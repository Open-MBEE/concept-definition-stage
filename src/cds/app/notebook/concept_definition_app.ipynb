# %% [markdown]
# # Concept Definition
# The substance lives in `cds` (`.py`/`.ttl`); this notebook is a thin shell (spec §12).

# %%
from cds.app.widgets import bootstrap_session, build_app

build_app(bootstrap_session())
